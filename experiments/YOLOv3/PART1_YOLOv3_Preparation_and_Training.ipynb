# %% [markdown]
# Custom dataset preparation and Training using YOLOv3 darknet
# ---

# %% [markdown]
# Labelling from scratch
# - Create **custom_data** folder on local with images to train and test. Can use Imageye as chrome extension to download images in bulk for each class
# - Download **LabelImg** from https://github.com/tzutalin/labelImg. This is a visual GUI-software for marking bounded boxes of objects and generating annotation files.
# - Go to installation folder of LabelImg>data. Remove the contents of Predefined classes file and add custom classes in order of detection
# - Launch LabelImg via anaconda(using python labelImg.py), go to View and enable autosave mode.
# - Above Create RectBox, toggle on PascalVOC once to change to YOLO format
# - On LabelImg, select Open dir. Browse to custom_data folder, start annotating the 1st image using Create RectBox.
# - Annotate each object on images and tag to existing classes
# - Save each image once tagged, this creates the .txt file for that image in custom_data folder.
# **Note**   Both image and txt files should be inside custom_data folder and share the same names
# - Once all images are annotated, place **Rename_files.ipynb** into the custom_data folder and execute. This converts file names into sequential format
# - Zip the custom_data folder

# %% [markdown]
# **Google Drive Preparation**
# - Create a yolo_custom_model_Training folder on google drive
# - Move the custom_data.zip file to above folder
# - Create a **custom_weight** folder within yolo_custom_model_Training. Download pre-trained weights for the convolutional layers (154 MB): https://pjreddie.com/media/files/darknet53.conv.74 and move it to custom_weight folder
# - create **darknet** and **backup** folders within yolo_custom_model_Training

# %% [markdown]
# To access Google Drive Folder and Files

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# unzip dataset
# !unzip '/content/drive/MyDrive/Juice_Box/custom_data.zip' -d '/content/drive/MyDrive/Juice_Box/'
# Out:
# Archive:  /content/drive/MyDrive/Juice_Box/custom_data.zip
#    creating: /content/drive/MyDrive/Juice_Box/custom_data/
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil1.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil1.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil10.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil10.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil100.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil100.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil101.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil101.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil102.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil102.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil103.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil103.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil104.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil104.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil105.jpeg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil105.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil106.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil106.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil107.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil107.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil108.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil108.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil109.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil109.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil11.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil11.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil110.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil110.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil111.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil111.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil112.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil113.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil113.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil114.jpeg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil114.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil115.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil115.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil116.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil116.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil117.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil117.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil118.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil118.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil119.jpeg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil119.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil12.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil12.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil120.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil120.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil121.jpeg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil121.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil122.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil122.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil123.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil124.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil125.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil126.jpeg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil126.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil127.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil127.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil128.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil128.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil129.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil129.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil13.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil13.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil130.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil130.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil131.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil131.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil132.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil132.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil133.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil133.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil134.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil134.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil135.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil135.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil136.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil136.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil137.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil137.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil138.jpeg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil138.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil139.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil139.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil14.jpeg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil14.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil140.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil140.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil141.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil141.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil142.jpeg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil142.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil143.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil143.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil144.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil144.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil145.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil145.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil146.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil146.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil147.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil147.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil148.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil148.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil149.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil149.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil15.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil15.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil150.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil150.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil151.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil151.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil152.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil152.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil153.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil153.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil154.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil154.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil155.jpeg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil155.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil156.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil156.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil157.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil157.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil158.jpeg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil158.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil159.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil159.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil16.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil16.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil160.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil160.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil161.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil161.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil162.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil162.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil163.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil163.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil164.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil164.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil165.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil165.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil166.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil166.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil167.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil167.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil168.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil168.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil169.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil169.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil17.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil17.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil170.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil170.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil171.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil171.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil172.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil172.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil173.png
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil173.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil174.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil174.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil175.jpeg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil175.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil176.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil176.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil177.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil177.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil178.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil178.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil179.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil179.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil18.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil18.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil180.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil181.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil181.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil182.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil182.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil183.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil183.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil184.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil184.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil185.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil185.txt
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil186.png
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil187.jpeg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_fo
jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil79.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil8.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil8.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil80.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil80.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil81.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil81.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil82.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil82.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil83.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil83.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil84.jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil84.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil85.jpeg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil85.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil86.jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/aluminum_foil87.jpeg
# ...
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery25 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery250 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery250 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery251 .jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/battery251 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery252 .jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/battery252 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery253 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery253 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery254 .jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/battery254 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery255 .jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/battery255 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery256 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery256 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery258 .jpeg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/battery258 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery26 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery26 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery260 .jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/battery260 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery261 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery261 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery263 .jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/battery263 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery264 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery264 .txt
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/battery265 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery265 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery266 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery266 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery267 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery267 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery268 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery268 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery269 .jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/battery269 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery27 .jpeg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/battery27 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery270 .jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/battery270 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery271 .jpeg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery271 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery272 .jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/battery272 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery273 .jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/battery273 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery274 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery274 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery275 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery275 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery276 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery276 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery278 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery278 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery28 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery28 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery280 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery280 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery281 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery281 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery282 .jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/battery282 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery283 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery283 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery284 .jpeg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery284 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery29 .png
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery29 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery3 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery3 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery30 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery30 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery31 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery31 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery32 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery32 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery33 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery33 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery35 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery35 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery36 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery36 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery37 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery37 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery38 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery38 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery39 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery39 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery4 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery4 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery40 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery40 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery41 .jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/battery41 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery42 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery42 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery43 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery43 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery44 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery44 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery45 .jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/battery45 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery46 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery46 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery47 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery47 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery48 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery48 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery49 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery49 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery5 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery5 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery50 .jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/battery50 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery51 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery51 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery52 .jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/battery52 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery53 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery53 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery54 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery54 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery55 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery55 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery56 .jpeg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery56 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery57 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery57 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery58 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery58 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery59 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery59 .txt
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/battery6 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery6 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery60 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery60 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery61 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery61 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery62 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery62 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery63 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery64 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery64 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery66 .jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/battery66 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery67 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery67 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery68 .jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/battery68 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery69 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery69 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery7 .jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/battery7 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery70 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery70 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery72 .jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/battery72 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery74 .jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/battery74 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery75 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery75 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery76 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery76 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery77 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery77 .txt
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/battery78 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery79 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery79 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery8 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery8 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery80 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery80 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery81 .jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/battery81 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery82 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery83 .jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/battery83 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery84 .jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/battery84 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery85 .jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/battery85 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery86 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery86 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery87 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery87 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery88 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery88 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery9 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery9 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery91 .jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/battery91 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery92 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery92 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery93 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery93 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery94 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery94 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery95 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery95 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery96 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery96 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery97 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery97 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery98 .jpg
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery98 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/battery99 .jpg
#  extracting: /content/drive/MyDrive/Juice_Box/custom_data/battery99 .txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/classes.names
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/classes.txt
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/creating-files-data-and-name.py
#   inflating: /content/drive/MyDrive/Juice_Box/custom_data/creating-train-and-test-txt-files.py

# %% [markdown]
# **Install modified Version of Darknet**

# %%
# %cd '/content/drive/MyDrive/Juice_Box/darknet'
# !git clone 'https://github.com/AlexeyAB/darknet' '/content/drive/MyDrive/Juice_Box/darknet'
# Out:
# /content/drive/MyDrive/Juice_Box/darknet
# Cloning into '/content/drive/MyDrive/Juice_Box/darknet'...
# remote: Enumerating objects: 14730, done.
# remote: Total 14730 (delta 0), reused 0 (delta 0), pack-reused 14730
# Receiving objects: 100% (14730/14730), 13.27 MiB | 6.35 MiB/s, done.
# Resolving deltas: 100% (10020/10020), done.
# Checking out files: 100% (2023/2023), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **More configurations on google drive**
# - Edit **makefile** in darknet folder by setting GPU=1,CUDNN=1 and OPENCV=1(lines 1,2,4 respectively)
# - Upload the 2 .py files creating-files-data-and-name.py and creating-train-and-test-txt-files.py(shared via google drive yolo_custom_model_Training > Python Notebooks) to custom_data folder on googledrive
# - Download classes.txt from custom_data and rename to classes.names. Upload this to custom_data folder

# %%
# %cd '/content/drive/MyDrive/Juice_Box/'
# !python custom_data/creating-files-data-and-name.py
# Out:
# /content/drive/MyDrive/Juice_Box

# %%
# Run only if the train and test files are not manually created and uploaded to custom_data folder
# %cd '/content/drive/MyDrive/Juice_Box/'
# !python custom_data/creating-train-and-test-txt-files.py
# Out:
# /content/drive/MyDrive/Juice_Box

# %% [markdown]
# **Custom configurations**
# Copy the yolov3.cfg file from darknet>cfg folder and save as yolov3_custom.cfg file. Upload this yolov3_custom.cfg file to same folder once below changes are done:
# - Lines 3 and 4 for testing commented
# - Lines 6 and 7 for training uncommented
# - Line 20 maxbatches(# of iterations for training yolo v3) edited from 500200 to (num_classes*2000). Never go below 2000. In POC, we used 3 classes, so this parameter was set to 6000
# - Line 22 steps edited to about 20% less than the batches(experiment)
#
# **Transfer Learning Step**
# - Edit last 3 YOLO layers and their preceeding Conv layers as follows:
#    - classes on Lines 610,696 and 783 to 3(for POC)
#    - filters on lines 603,689 and 776 to 24 (num_classes+5)*3

# %%
# Compile darknet (build)
# %cd '/content/drive/MyDrive/Juice_Box/darknet'
# !make clean
# !make
# Out:
# /content/drive/MyDrive/Juice_Box/darknet
# rm -rf ./obj/image_opencv.o ./obj/http_stream.o ./obj/gemm.o ./obj/utils.o ./obj/dark_cuda.o ./obj/convolutional_layer.o ./obj/list.o ./obj/image.o ./obj/activations.o ./obj/im2col.o ./obj/col2im.o ./obj/blas.o ./obj/crop_layer.o ./obj/dropout_layer.o ./obj/maxpool_layer.o ./obj/softmax_layer.o ./obj/data.o ./obj/matrix.o ./obj/network.o ./obj/connected_layer.o ./obj/cost_layer.o ./obj/parser.o ./obj/option_list.o ./obj/darknet.o ./obj/detection_layer.o ./obj/captcha.o ./obj/route_layer.o ./obj/writing.o ./obj/box.o ./obj/nightmare.o ./obj/normalization_layer.o ./obj/avgpool_layer.o ./obj/coco.o ./obj/dice.o ./obj/yolo.o ./obj/detector.o ./obj/layer.o ./obj/compare.o ./obj/classifier.o ./obj/local_layer.o ./obj/swag.o ./obj/shortcut_layer.o ./obj/activation_layer.o ./obj/rnn_layer.o ./obj/gru_layer.o ./obj/rnn.o ./obj/rnn_vid.o ./obj/crnn_layer.o ./obj/demo.o ./obj/tag.o ./obj/cifar.o ./obj/go.o ./obj/batchnorm_layer.o ./obj/art.o ./obj/region_layer.o ./obj/reorg_layer.o ./obj/reorg_old_layer.o ./obj/super.o ./obj/voxel.o ./obj/tree.o ./obj/yolo_layer.o ./obj/gaussian_yolo_layer.o ./obj/upsample_layer.o ./obj/lstm_layer.o ./obj/conv_lstm_layer.o ./obj/scale_channels_layer.o ./obj/sam_layer.o ./obj/convolutional_kernels.o ./obj/activation_kernels.o ./obj/im2col_kernels.o ./obj/col2im_kernels.o ./obj/blas_kernels.o ./obj/crop_layer_kernels.o ./obj/dropout_layer_kernels.o ./obj/maxpool_layer_kernels.o ./obj/network_kernels.o ./obj/avgpool_layer_kernels.o darknet
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
#              ^~
# ./src/image_opencv.cpp:1130:10: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#           if (iteration_old != 0){
#           ^~
# ./src/image_opencv.cpp: In function ‘void cv_draw_object(image, float*, int, int, int*, float*, int*, int, char**)’:
# ./src/image_opencv.cpp:1424:14: warning: unused variable ‘buff’ [-Wunused-variable]
#          char buff[100];
#               ^~~~
# ./src/image_opencv.cpp:1400:9: warning: unused variable ‘it_tb_res’ [-Wunused-variable]
#      int it_tb_res = cv::createTrackbar(it_trackbar_name, window_name, &it_trackbar_value, 1000);
#          ^~~~~~~~~
# ./src/image_opencv.cpp:1404:9: warning: unused variable ‘lr_tb_res’ [-Wunused-variable]
#      int lr_tb_res = cv::createTrackbar(lr_trackbar_name, window_name, &lr_trackbar_value, 20);
#          ^~~~~~~~~
# ./src/image_opencv.cpp:1408:9: warning: unused variable ‘cl_tb_res’ [-Wunused-variable]
#      int cl_tb_res = cv::createTrackbar(cl_trackbar_name, window_name, &cl_trackbar_value, classes-1);
#          ^~~~~~~~~
# ./src/image_opencv.cpp:1411:9: warning: unused variable ‘bo_tb_res’ [-Wunused-variable]
#      int bo_tb_res = cv::createTrackbar(bo_trackbar_name, window_name, boxonly, 1);
#          ^~~~~~~~~
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/http_stream.cpp -o obj/http_stream.o
# In file included from ./src/http_stream.cpp:580:0:
# ./src/httplib.h:129:0: warning: "INVALID_SOCKET" redefined
#  #define INVALID_SOCKET (-1)
#
# ./src/http_stream.cpp:73:0: note: this is the location of the previous definition
#  #define INVALID_SOCKET -1
#
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:249:21: warning: unused variable ‘n’ [-Wunused-variable]
#                  int n = _write(client, outputbuf, outlen);
#                      ^
# ./src/http_stream.cpp: In member function ‘bool MJPG_sender::write(const cv::Mat&)’:
# ./src/http_stream.cpp:507:113: warning: format ‘%zu’ expects argument of type ‘size_t’, but argument 3 has type ‘int’ [-Wformat=]
#                  sprintf(head, "--mjpegstream\r\nContent-Type: image/jpeg\r\nContent-Length: %zu\r\n\r\n", outlen);
#                                                                                                                  ^
# ./src/http_stream.cpp: In function ‘void set_track_id(detection*, int, float, float, float, int, int, int)’:
# ./src/http_stream.cpp:863:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#          for (int i = 0; i < v.size(); ++i) {
#                          ~~^~~~~~~~~~
# ./src/http_stream.cpp:871:33: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#      for (int old_id = 0; old_id < old_dets.size(); ++old_id) {
#                           ~~~~~~~^~~~~~~~~~~~~~~~~
# ./src/http_stream.cpp:890:31: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#      for (int index = 0; index < new_dets_num*old_dets.size(); ++index) {
#                          ~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ./src/http_stream.cpp:926:28: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#      if (old_dets_dq.size() > deque_size) old_dets_dq.pop_front();
#          ~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘convolution_2d’:
# ./src/gemm.c:2038:15: warning: unused variable ‘out_w’ [-Wunused-variable]
#      const int out_w = (w + 2 * pad - ksize) / stride + 1;    // output_width=input_width for stride=1 and pad=1
#                ^~~~~
# ./src/gemm.c:2037:15: warning: unused variable ‘out_h’ [-Wunused-variable]
#      const int out_h = (h + 2 * pad - ksize) / stride + 1;    // output_height=input_height for stride=1 and pad=1
#                ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/utils.c -o obj/utils.o
# ./src/utils.c: In function ‘custom_hash’:
# ./src/utils.c:1045:12: warning: suggest parentheses around assignment used as truth value [-Wparentheses]
#      while (c = *str++)
#             ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/dark_cuda.c -o obj/dark_cuda.o
# ./src/dark_cuda.c: In function ‘cudnn_check_error_extended’:
# ./src/dark_cuda.c:228:20: warning: comparison between ‘cudaError_t {aka enum cudaError}’ and ‘enum <anonymous>’ [-Wenum-compare]
#          if (status != CUDNN_STATUS_SUCCESS)
#                     ^~
# ./src/dark_cuda.c: At top level:
# ./src/dark_cuda.c:306:14: warning: type defaults to ‘int’ in declaration of ‘max_events’ [-Wimplicit-int]
#  static const max_events = 1024;
#               ^~~~~~~~~~
# ./src/dark_cuda.c: In function ‘pre_allocate_pinned_memory’:
# ./src/dark_cuda.c:364:40: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#          printf("pre_allocate: size = %Iu MB, num_of_blocks = %Iu, block_size = %Iu MB \n",
#                                       ~~^
#                                       %Ilu
#              size / (1024*1024), num_of_blocks, pinned_block_size / (1024 * 1024));
#              ~~~~~~~~~~~~~~~~~~
# ./src/dark_cuda.c:364:64: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 3 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
#          printf("pre_allocate: size = %Iu MB, num_of_blocks = %Iu, block_size = %Iu MB \n",
#                                                               ~~^
#                                                               %Ilu
# ./src/dark_cuda.c:364:82: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 4 has type ‘long unsigned int’ [-Wformat=]
#          printf("pre_allocate: size = %Iu MB, num_of_blocks = %Iu, block_size = %Iu MB \n",
#                                                                                 ~~^
#                                                                                 %Ilu
# ./src/dark_cuda.c:374:37: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
#                  printf(" Allocated %d pinned block \n", pinned_block_size);
#                                     ~^
#                                     %ld
# ./src/dark_cuda.c: In function ‘cuda_make_array_pinned_preallocated’:
# ./src/dark_cuda.c:395:43: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#              printf("\n Pinned block_id = %d, filled = %f %% \n", pinned_block_id, filled);
#                                           ~^
#                                           %ld
# ./src/dark_cuda.c:410:64: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#              printf("Try to allocate new pinned memory, size = %d MB \n", size / (1024 * 1024));
#                                                                ~^         ~~~~~~~~~~~~~~~~~~~~
#                                                                %ld
# ./src/dark_cuda.c:416:63: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#              printf("Try to allocate new pinned BLOCK, size = %d MB \n", size / (1024 * 1024));
#                                                               ~^         ~~~~~~~~~~~~~~~~~~~~
#                                                               %ld
# At top level:
# ./src/dark_cuda.c:256:23: warning: ‘switchBlasHandle’ defined but not used [-Wunused-variable]
#  static cublasHandle_t switchBlasHandle[16];
#                        ^~~~~~~~~~~~~~~~
# ./src/dark_cuda.c:255:12: warning: ‘switchBlasInit’ defined but not used [-Wunused-variable]
#  static int switchBlasInit[16] = { 0 };
#             ^~~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/convolutional_layer.c -o obj/convolutional_layer.o
# ./src/convolutional_layer.c: In function ‘forward_convolutional_layer’:
# ./src/convolutional_layer.c:1341:32: warning: unused variable ‘t_intput_size’ [-Wunused-variable]
#                          size_t t_intput_size = binary_transpose_align_input(k, n, state.workspace, &l.t_bit_input, ldb_align, l.bit_align);
#                                 ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/list.c -o obj/list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image.c -o obj/image.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/activations.c -o obj/activations.o
# ./src/activations.c: In function ‘activate’:
# ./src/activations.c:79:5: warning: enumeration value ‘RELU6’ not handled in switch [-Wswitch]
#      switch(a){
#      ^~~~~~
# ./src/activations.c:79:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘HARD_MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN_SOFTMAX’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN_SOFTMAX_MAXVAL’ not handled in switch [-Wswitch]
# ./src/activations.c: In function ‘gradient’:
# ./src/activations.c:310:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
#      switch(a){
#      ^~~~~~
# ./src/activations.c:310:5: warning: enumeration value ‘MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:310:5: warning: enumeration value ‘HARD_MISH’ not handled in switch [-Wswitch]
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/im2col.c -o obj/im2col.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/col2im.c -o obj/col2im.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/blas.c -o obj/blas.o
# ./src/blas.c: In function ‘backward_shortcut_multilayer_cpu’:
# ./src/blas.c:207:21: warning: unused variable ‘out_index’ [-Wunused-variable]
#                  int out_index = id;
#                      ^~~~~~~~~
# ./src/blas.c: In function ‘find_sim’:
# ./src/blas.c:597:59: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_sim(): sim isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                           ~^
#                                                           %ld
# ./src/blas.c:597:67: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_sim(): sim isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                                   ~^
#                                                                   %ld
# ./src/blas.c:597:75: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_sim(): sim isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                                           ~^
#                                                                           %ld
# ./src/blas.c: In function ‘find_P_constrastive’:
# ./src/blas.c:611:68: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_P_constrastive(): P isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                                    ~^
#                                                                    %ld
# ./src/blas.c:611:76: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_P_constrastive(): P isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                                            ~^
#                                                                            %ld
# ./src/blas.c:611:84: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_P_constrastive(): P isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                                                    ~^
#                                                                                    %ld
# ./src/blas.c: In function ‘P_constrastive_f’:
# ./src/blas.c:651:79: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          fprintf(stderr, " Error: in P_constrastive must be i != l, while i = %d, l = %d \n", i, l);
#                                                                               ~^
#                                                                               %ld
# ./src/blas.c:651:87: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          fprintf(stderr, " Error: in P_constrastive must be i != l, while i = %d, l = %d \n", i, l);
#                                                                                       ~^
#                                                                                       %ld
# ./src/blas.c: In function ‘P_constrastive’:
# ./src/blas.c:785:79: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          fprintf(stderr, " Error: in P_constrastive must be i != l, while i = %d, l = %d \n", i, l);
#                                                                               ~^
#                                                                               %ld
# ./src/blas.c:785:87: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          fprintf(stderr, " Error: in P_constrastive must be i != l, while i = %d, l = %d \n", i, l);
#                                                                                       ~^
#                                                                                       %ld
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/crop_layer.c -o obj/crop_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/dropout_layer.c -o obj/dropout_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/maxpool_layer.c -o obj/maxpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/softmax_layer.c -o obj/softmax_layer.o
# ./src/softmax_layer.c: In function ‘make_contrastive_layer’:
# ./src/softmax_layer.c:203:101: warning: format ‘%d’ expects argument of type ‘int’, but argument 9 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
#      fprintf(stderr, "contrastive %4d x%4d x%4d x emb_size %4d x batch: %4d  classes = %4d, step = %4d \n", w, h, l.n, l.embedding_size, batch, l.classes, step);
#                                                                                                    ~~^
#                                                                                                    %4ld
# ./src/softmax_layer.c: In function ‘forward_contrastive_layer’:
# ./src/softmax_layer.c:244:27: warning: variable ‘max_truth’ set but not used [-Wunused-but-set-variable]
#                      float max_truth = 0;
#                            ^~~~~~~~~
# ./src/softmax_layer.c:423:71: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
#              printf(" Error: too large number of bboxes: contr_size = %d > max_contr_size  = %d \n", contr_size, max_contr_size);
#                                                                       ~^
#                                                                       %ld
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/data.c -o obj/data.o
# ./src/data.c: In function ‘load_data_detection’:
# ./src/data.c:1297:24: warning: unused variable ‘x’ [-Wunused-variable]
#                  int k, x, y;
#                         ^
# ./src/data.c:1090:43: warning: variable ‘r_scale’ set but not used [-Wunused-but-set-variable]
#      float r1 = 0, r2 = 0, r3 = 0, r4 = 0, r_scale = 0;
#                                            ^~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/matrix.c -o obj/matrix.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/network.c -o obj/network.o
# ./src/network.c: In function ‘train_network_waitkey’:
# ./src/network.c:434:13: warning: unused variable ‘ema_period’ [-Wunused-variable]
#          int ema_period = (net.max_batches - ema_start_point - 1000) * (1.0 - net.ema_alpha);
#              ^~~~~~~~~~
# ./src/network.c: In function ‘resize_network’:
# ./src/network.c:659:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net->input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped))
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/network.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4707:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/connected_layer.c -o obj/connected_layer.o
# ./src/connected_layer.c: In function ‘forward_connected_layer_gpu’:
# ./src/connected_layer.c:346:11: warning: unused variable ‘one’ [-Wunused-variable]
#      float one = 1;    // alpha[0], beta[0]
#            ^~~
# ./src/connected_layer.c:344:13: warning: unused variable ‘c’ [-Wunused-variable]
#      float * c = l.output_gpu;
#              ^
# ./src/connected_layer.c:343:13: warning: unused variable ‘b’ [-Wunused-variable]
#      float * b = l.weights_gpu;
#              ^
# ./src/connected_layer.c:342:13: warning: unused variable ‘a’ [-Wunused-variable]
#      float * a = state.input;
#              ^
# ./src/connected_layer.c:341:9: warning: unused variable ‘n’ [-Wunused-variable]
#      int n = l.outputs;
#          ^
# ./src/connected_layer.c:340:9: warning: unused variable ‘k’ [-Wunused-variable]
#      int k = l.inputs;
#          ^
# ./src/connected_layer.c:339:9: warning: unused variable ‘m’ [-Wunused-variable]
#      int m = l.batch;
#          ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/cost_layer.c -o obj/cost_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/parser.c -o obj/parser.o
# ./src/parser.c: In function ‘parse_network_cfg_custom’:
# ./src/parser.c:1689:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net.input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped)) net.input_pinned_cpu_flag = 1;
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/activation_layer.h:4,
#                  from ./src/parser.c:6:
# /usr/local/cuda/include/cuda_runtime_api.h:4707:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/parser.c: In function ‘get_classes_multipliers’:
# ./src/parser.c:431:29: warning: argument 1 range [18446744071562067968, 18446744073709551615] exceeds maximum object size 9223372036854775807 [-Walloc-size-larger-than=]
#          classes_multipliers = (float *)calloc(classes_counters, sizeof(float));
#          ~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from ./src/parser.c:3:0:
# /usr/include/stdlib.h:541:14: note: in a call to allocation function ‘calloc’ declared here
#  extern void *calloc (size_t __nmemb, size_t __size)
#               ^~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/option_list.c -o obj/option_list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/darknet.c -o obj/darknet.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/detection_layer.c -o obj/detection_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/captcha.c -o obj/captcha.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/route_layer.c -o obj/route_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/writing.c -o obj/writing.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/box.c -o obj/box.o
# ./src/box.c: In function ‘box_iou_kind’:
# ./src/box.c:154:5: warning: enumeration value ‘MSE’ not handled in switch [-Wswitch]
#      switch(iou_kind) {
#      ^~~~~~
# ./src/box.c: In function ‘diounms_sort’:
# ./src/box.c:898:27: warning: unused variable ‘beta_prob’ [-Wunused-variable]
#                      float beta_prob = pow(dets[j].prob[k], 2) / sum_prob;
#                            ^~~~~~~~~
# ./src/box.c:897:27: warning: unused variable ‘alpha_prob’ [-Wunused-variable]
#                      float alpha_prob = pow(dets[i].prob[k], 2) / sum_prob;
#                            ^~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/nightmare.c -o obj/nightmare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/normalization_layer.c -o obj/normalization_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/avgpool_layer.c -o obj/avgpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/coco.c -o obj/coco.o
# ./src/coco.c: In function ‘validate_coco_recall’:
# ./src/coco.c:248:11: warning: unused variable ‘base’ [-Wunused-variable]
#      char *base = "results/comp4_det_test_";
#            ^~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/dice.c -o obj/dice.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/yolo.c -o obj/yolo.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/detector.c -o obj/detector.o
# ./src/detector.c: In function ‘train_detector’:
# ./src/detector.c:386:72: warning: suggest parentheses around ‘&&’ within ‘||’ [-Wparentheses]
#              (iteration >= (iter_save + 1000) || iteration % 1000 == 0) && net.max_batches < 10000)
#              ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~
# ./src/detector.c: In function ‘print_cocos’:
# ./src/detector.c:486:29: warning: format not a string literal and no format arguments [-Wformat-security]
#                  fprintf(fp, buff);
#                              ^~~~
# ./src/detector.c: In function ‘eliminate_bdd’:
# ./src/detector.c:579:21: warning: statement with no effect [-Wunused-value]
#                      for (k; buf[k + n] != '\0'; k++)
#                      ^~~
# ./src/detector.c: In function ‘validate_detector’:
# ./src/detector.c:700:13: warning: unused variable ‘mkd2’ [-Wunused-variable]
#          int mkd2 = make_directory(buff2, 0777);
#              ^~~~
# ./src/detector.c:698:13: warning: unused variable ‘mkd’ [-Wunused-variable]
#          int mkd = make_directory(buff, 0777);
#              ^~~
# ./src/detector.c: In function ‘validate_detector_map’:
# ./src/detector.c:1332:15: warning: unused variable ‘class_recall’ [-Wunused-variable]
#          float class_recall = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)(truth_classes_count[i] - tp_for_thresh_per_class[i]));
#                ^~~~~~~~~~~~
# ./src/detector.c:1331:15: warning: unused variable ‘class_precision’ [-Wunused-variable]
#          float class_precision = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)fp_for_thresh_per_class[i]);
#                ^~~~~~~~~~~~~~~
# ./src/detector.c: In function ‘draw_object’:
# ./src/detector.c:1867:19: warning: unused variable ‘inv_loss’ [-Wunused-variable]
#              float inv_loss = 1.0 / max_val_cmp(0.01, avg_loss);
#                    ^~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/layer.c -o obj/layer.o
# ./src/layer.c: In function ‘free_layer_custom’:
# ./src/layer.c:208:68: warning: suggest parentheses around ‘&&’ within ‘||’ [-Wparentheses]
#      if (l.delta_gpu && (l.optimized_memory < 1 || l.keep_delta_gpu && l.optimized_memory < 3)) cuda_free(l.delta_gpu), l.delta_gpu = NULL;
#                                                    ~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/compare.c -o obj/compare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/classifier.c -o obj/classifier.o
# ./src/classifier.c: In function ‘train_classifier’:
# ./src/classifier.c:146:9: warning: unused variable ‘count’ [-Wunused-variable]
#      int count = 0;
#          ^~~~~
# ./src/classifier.c: In function ‘predict_classifier’:
# ./src/classifier.c:855:13: warning: unused variable ‘time’ [-Wunused-variable]
#      clock_t time;
#              ^~~~
# ./src/classifier.c: In function ‘demo_classifier’:
# ./src/classifier.c:1287:49: warning: unused variable ‘tval_result’ [-Wunused-variable]
#          struct timeval tval_before, tval_after, tval_result;
#                                                  ^~~~~~~~~~~
# ./src/classifier.c:1287:37: warning: unused variable ‘tval_after’ [-Wunused-variable]
#          struct timeval tval_before, tval_after, tval_result;
#                                      ^~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/local_layer.c -o obj/local_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/swag.c -o obj/swag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/shortcut_layer.c -o obj/shortcut_layer.o
# ./src/shortcut_layer.c: In function ‘make_shortcut_layer’:
# ./src/shortcut_layer.c:55:15: warning: unused variable ‘scale’ [-Wunused-variable]
#          float scale = sqrt(2. / l.nweights);
#                ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/activation_layer.c -o obj/activation_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/rnn_layer.c -o obj/rnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/gru_layer.c -o obj/gru_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/rnn.c -o obj/rnn.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/rnn_vid.c -o obj/rnn_vid.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/crnn_layer.c -o obj/crnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/demo.c -o obj/demo.o
# ./src/demo.c: In function ‘detect_in_thread’:
# ./src/demo.c:98:15: warning: unused variable ‘l’ [-Wunused-variable]
#          layer l = net.layers[net.n - 1];
#                ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/tag.c -o obj/tag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/cifar.c -o obj/cifar.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/go.c -o obj/go.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/batchnorm_layer.c -o obj/batchnorm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/art.c -o obj/art.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/region_layer.c -o obj/region_layer.o
# ./src/region_layer.c: In function ‘resize_region_layer’:
# ./src/region_layer.c:59:9: warning: unused variable ‘old_h’ [-Wunused-variable]
#      int old_h = l->h;
#          ^~~~~
# ./src/region_layer.c:58:9: warning: unused variable ‘old_w’ [-Wunused-variable]
#      int old_w = l->w;
#          ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/reorg_layer.c -o obj/reorg_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/reorg_old_layer.c -o obj/reorg_old_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/super.c -o obj/super.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/voxel.c -o obj/voxel.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/tree.c -o obj/tree.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/yolo_layer.c -o obj/yolo_layer.o
# ./src/yolo_layer.c: In function ‘make_yolo_layer’:
# ./src/yolo_layer.c:68:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.output, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.output_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4707:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c:75:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.delta, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.delta_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4707:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c: In function ‘resize_yolo_layer’:
# ./src/yolo_layer.c:106:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->output, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4707:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c:115:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->delta, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
# ...
#                                        ^~~~~~~~~~~~~
# ./src/gaussian_yolo_layer.c:78:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.delta, batch*l.outputs * sizeof(float), cudaHostRegisterMapped)) l.delta_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:4707:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/gaussian_yolo_layer.c: In function ‘resize_gaussian_yolo_layer’:
# ./src/gaussian_yolo_layer.c:110:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->output, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:4707:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/gaussian_yolo_layer.c:119:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->delta, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:4707:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/upsample_layer.c -o obj/upsample_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/lstm_layer.c -o obj/lstm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/conv_lstm_layer.c -o obj/conv_lstm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/scale_channels_layer.c -o obj/scale_channels_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/sam_layer.c -o obj/sam_layer.o
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/convolutional_kernels.cu -o obj/convolutional_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/activation_kernels.cu -o obj/activation_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# ./src/activation_kernels.cu(263): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(263): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(263): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(263): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/im2col_kernels.cu -o obj/im2col_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/col2im_kernels.cu -o obj/col2im_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/blas_kernels.cu -o obj/blas_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu: In function ‘void backward_shortcut_multilayer_gpu(int, int, int, int*, float**, float*, float*, float*, float*, int, float*, float**, WEIGHTS_NORMALIZATION_T)’:
# ./src/blas_kernels.cu:1130:5: warning: variable ‘step’ set but not used [-Wunused-but-set-variable]
#      int step = 0;
#      ^~~~
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/crop_layer_kernels.cu -o obj/crop_layer_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/dropout_layer_kernels.cu -o obj/dropout_layer_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/maxpool_layer_kernels.cu -o obj/maxpool_layer_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/network_kernels.cu -o obj/network_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# ./src/network_kernels.cu(364): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu(364): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu(364): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu(364): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu: In function ‘float train_network_datum_gpu(network, float*, float*)’:
# ./src/network_kernels.cu:364:7: warning: variable ‘l’ set but not used [-Wunused-but-set-variable]
#          layer l = net.layers[net.n - 1];
#        ^
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/avgpool_layer_kernels.cu -o obj/avgpool_layer_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include obj/image_opencv.o obj/http_stream.o obj/gemm.o obj/utils.o obj/dark_cuda.o obj/convolutional_layer.o obj/list.o obj/image.o obj/activations.o obj/im2col.o obj/col2im.o obj/blas.o obj/crop_layer.o obj/dropout_layer.o obj/maxpool_layer.o obj/softmax_layer.o obj/data.o obj/matrix.o obj/network.o obj/connected_layer.o obj/cost_layer.o obj/parser.o obj/option_list.o obj/darknet.o obj/detection_layer.o obj/captcha.o obj/route_layer.o obj/writing.o obj/box.o obj/nightmare.o obj/normalization_layer.o obj/avgpool_layer.o obj/coco.o obj/dice.o obj/yolo.o obj/detector.o obj/layer.o obj/compare.o obj/classifier.o obj/local_layer.o obj/swag.o obj/shortcut_layer.o obj/activation_layer.o obj/rnn_layer.o obj/gru_layer.o obj/rnn.o obj/rnn_vid.o obj/crnn_layer.o obj/demo.o obj/tag.o obj/cifar.o obj/go.o obj/batchnorm_layer.o obj/art.o obj/region_layer.o obj/reorg_layer.o obj/reorg_old_layer.o obj/super.o obj/voxel.o obj/tree.o obj/yolo_layer.o obj/gaussian_yolo_layer.o obj/upsample_layer.o obj/lstm_layer.o obj/conv_lstm_layer.o obj/scale_channels_layer.o obj/sam_layer.o obj/convolutional_kernels.o obj/activation_kernels.o obj/im2col_kernels.o obj/col2im_kernels.o obj/blas_kernels.o obj/crop_layer_kernels.o obj/dropout_layer_kernels.o obj/maxpool_layer_kernels.o obj/network_kernels.o obj/avgpool_layer_kernels.o -o darknet -lm -pthread `pkg-config --libs opencv4 2> /dev/null || pkg-config --libs opencv` -L/usr/local/cuda/lib64 -lcuda -lcudart -lcublas -lcurand -L/usr/local/cudnn/lib64 -lcudnn -lstdc++

# %%
#Check if darknet compiled correctly
# Check if compiled correctly
! darknet/darknet
# should return : usage: ./darknet <function>
# Out:
# usage: darknet/darknet <function>

# %% [markdown]
# **Train to detect your custom objects**

# %% [markdown]
# This will create weights in yolo_custom_model_Training > backup folder.
# If there are any input files that got rejected during training, it gets logged in a badlist within yolo_custom_model_Training

# %%
# %cd '/content/drive/MyDrive/Juice_Box'
# !darknet/darknet detector train custom_data/labelled_data.data darknet/cfg/yolov3_custom.cfg custom_weight/darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.483777), count: 4, class_loss = 2.749210, iou_loss = 0.623124, total_loss = 3.372334
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.027490, iou_loss = 0.000000, total_loss = 0.027490
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.019430, iou_loss = 0.000000, total_loss = 0.019430
#  total_bbox = 30815, rewritten_bbox = 0.162259 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.371734), count: 4, class_loss = 2.473497, iou_loss = 1.350051, total_loss = 3.823548
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.024699, iou_loss = 0.000000, total_loss = 0.024699
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.019177, iou_loss = 0.000000, total_loss = 0.019177
#  total_bbox = 30819, rewritten_bbox = 0.162238 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.580018), count: 5, class_loss = 3.362626, iou_loss = 1.419548, total_loss = 4.782175
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.025418, iou_loss = 0.000000, total_loss = 0.025418
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.021186, iou_loss = 0.000000, total_loss = 0.021186
#  total_bbox = 30824, rewritten_bbox = 0.162211 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.395150), count: 6, class_loss = 3.440606, iou_loss = 2.606054, total_loss = 6.046659
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.125166), count: 1, class_loss = 0.955700, iou_loss = 1.378062, total_loss = 2.333763
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.021635, iou_loss = 0.000000, total_loss = 0.021635
#  total_bbox = 30831, rewritten_bbox = 0.162174 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.613468), count: 3, class_loss = 2.071454, iou_loss = 0.281968, total_loss = 2.353422
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.025820, iou_loss = 0.000000, total_loss = 0.025820
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.019549, iou_loss = 0.000000, total_loss = 0.019549
#  total_bbox = 30834, rewritten_bbox = 0.162159 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.454771), count: 6, class_loss = 3.689083, iou_loss = 1.992307, total_loss = 5.681391
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.486849), count: 1, class_loss = 0.856972, iou_loss = 0.346752, total_loss = 1.203725
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.017429, iou_loss = 0.000000, total_loss = 0.017429
#  total_bbox = 30841, rewritten_bbox = 0.162122 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.474557), count: 3, class_loss = 1.970836, iou_loss = 1.844560, total_loss = 3.815396
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.025062, iou_loss = 0.000000, total_loss = 0.025062
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.018913, iou_loss = 0.000000, total_loss = 0.018913
#  total_bbox = 30844, rewritten_bbox = 0.162106 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.371310), count: 4, class_loss = 2.487251, iou_loss = 1.362869, total_loss = 3.850119
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.301980), count: 1, class_loss = 0.848211, iou_loss = 0.592839, total_loss = 1.441050
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.018963, iou_loss = 0.000000, total_loss = 0.018963
#  total_bbox = 30849, rewritten_bbox = 0.162080 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.628202), count: 3, class_loss = 1.669453, iou_loss = 0.298493, total_loss = 1.967946
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.464836), count: 2, class_loss = 1.619224, iou_loss = 0.705569, total_loss = 2.324792
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.021120, iou_loss = 0.000000, total_loss = 0.021120
#  total_bbox = 30854, rewritten_bbox = 0.162054 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.188698), count: 2, class_loss = 1.863463, iou_loss = 2.796018, total_loss = 4.659480
#  total_bbox = 37110, rewritten_bbox = 0.169766 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.595504), count: 6, class_loss = 2.809652, iou_loss = 1.282425, total_loss = 4.092077
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.001437, iou_loss = 0.000000, total_loss = 0.001437
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000979, iou_loss = 0.000000, total_loss = 0.000979
#  total_bbox = 37116, rewritten_bbox = 0.169738 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.433980), count: 2, class_loss = 0.672417, iou_loss = 0.529785, total_loss = 1.202202
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.321419), count: 3, class_loss = 2.293622, iou_loss = 1.837524, total_loss = 4.131145
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000890, iou_loss = 0.000000, total_loss = 0.000890
#  total_bbox = 37121, rewritten_bbox = 0.169715 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.402384), count: 5, class_loss = 2.750348, iou_loss = 1.641714, total_loss = 4.392062
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.534031), count: 1, class_loss = 0.689099, iou_loss = 0.230276, total_loss = 0.919375
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000997, iou_loss = 0.000000, total_loss = 0.000997
#  total_bbox = 37127, rewritten_bbox = 0.169688 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.532346), count: 4, class_loss = 1.471553, iou_loss = 0.946826, total_loss = 2.418379
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.001396, iou_loss = 0.000000, total_loss = 0.001396
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.001229, iou_loss = 0.000000, total_loss = 0.001229
#  total_bbox = 37131, rewritten_bbox = 0.169670 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.592644), count: 4, class_loss = 1.389953, iou_loss = 0.414649, total_loss = 1.804602
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.001386, iou_loss = 0.000000, total_loss = 0.001386
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000860, iou_loss = 0.000000, total_loss = 0.000860
#  total_bbox = 37135, rewritten_bbox = 0.169651 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.391392), count: 6, class_loss = 2.666384, iou_loss = 3.087034, total_loss = 5.753417
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.192397), count: 2, class_loss = 1.324845, iou_loss = 2.556865, total_loss = 3.881710
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000843, iou_loss = 0.000000, total_loss = 0.000843
#  total_bbox = 37143, rewritten_bbox = 0.169615 %
#
#  414: 1.436111, 1.521643 avg loss, 0.000029 rate, 9.230417 seconds, 26496 images, 19.811963 hours left
# Loaded: 0.000051 seconds
# Can't open label file. (This can be normal only if you use MSCOCO): custom_data/aluminum_foil290.txt
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.601359), count: 6, class_loss = 2.864695, iou_loss = 1.181449, total_loss = 4.046144
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.374672), count: 1, class_loss = 0.678968, iou_loss = 0.540707, total_loss = 1.219674
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.001170, iou_loss = 0.000000, total_loss = 0.001170
#  total_bbox = 37150, rewritten_bbox = 0.169583 %
# Can't open label file. (This can be normal only if you use MSCOCO): custom_data/aluminum_foil328.txt
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.641355), count: 4, class_loss = 1.692060, iou_loss = 0.422457, total_loss = 2.114517
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.001270, iou_loss = 0.000000, total_loss = 0.001270
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000762, iou_loss = 0.000000, total_loss = 0.000762
#  total_bbox = 37154, rewritten_bbox = 0.169565 %
# Can't open label file. (This can be normal only if you use MSCOCO): custom_data/battery82 .txt
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.552736), count: 4, class_loss = 2.576919, iou_loss = 0.680207, total_loss = 3.257126
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.462381), count: 1, class_loss = 0.699228, iou_loss = 0.266730, total_loss = 0.965959
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.343608), count: 1, class_loss = 0.914252, iou_loss = 0.208768, total_loss = 1.123020
#  total_bbox = 37160, rewritten_bbox = 0.169537 %

# %% [markdown]
# Once training is complete, get **yolov3_custom_final.weights** from path `custom_data\backup\`
#
#
# *   After each set of iterations you can stop and later start training from this point. For example, after 1000 iterations you can stop training, and later just copy yolov3_custom_1000.weights from `custom_data\backup\`
